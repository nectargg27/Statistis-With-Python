# %%
import numpy as np
import pandas as pd

# %%
# The file name string that holds our .csv file
fname = "Cartwheeldata.csv"

# Read the .csv file and store it as a Pandas Data Frame
df = pd.read_csv(fname)

# Print the object type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
# 5   6   24      M            2       N             0    75.0      71.0
# 6   7   28      M            2       N             0    75.0      76.0
# 7   8   22      F            1       N             0    65.0      62.0
# 8   9   29      M            2       Y             1    74.0      73.0
# 9  10   33      F            1       Y             1    63.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4
# 5          81        N              0      3
# 6         107        Y              1     10
# 7          98        Y              1      9
# 8         106        N              0      5
# 9          65        Y              1      8

# %%
df.dtypes
# Out:
# ID                 int64
# Age                int64
# Gender            object
# GenderGroup        int64
# Glasses           object
# GlassesGroup       int64
# Height           float64
# Wingspan         float64
# CWDistance         int64
# Complete          object
# CompleteGroup      int64
# Score              int64
# dtype: object

# %%
#Use .loc() to specify a list of multiple column names
df.loc[:,["Gender", "GenderGroup"]]
# Out:
#    Gender  GenderGroup
# 0       F            1
# 1       F            1
# 2       F            1
# 3       F            1
# 4       M            2
# 5       M            2
# 6       M            2
# 7       F            1
# 8       M            2
# 9       F            1
# 10      M            2
# 11      F            1
# 12      F            1
# 13      F            1
# 14      M            2
# 15      M            2
# 16      F            1
# 17      M            2
# 18      M            2
# 19      F            1
# 20      M            2
# 21      M            2
# 22      M            2
# 23      M            2
# 24      F            1

# %%
pd.crosstab(df["Gender"], df["GenderGroup"])
# Out:
# GenderGroup   1   2
# Gender
# F            12   0
# M             0  13

# %%
df.loc(id,marialstatus)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.loc(id,marialstatus)
#
# NameError: name 'marialstatus' is not defined
